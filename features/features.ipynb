# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

mon_features = pd.read_csv('/content/drive/MyDrive/Machine_Learning/mon_features_modified.csv')
mon_labels = pd.read_csv('/content/drive/MyDrive//Machine_Learning/mon_labels.csv')
unmon_features = pd.read_csv('/content/drive/MyDrive//Machine_Learning/unmon_features_modified.csv')
unmon_labels = pd.read_csv('/content/drive/MyDrive//Machine_Learning/unmon_labels.csv')

# %%
import numpy as np

# %%
print(mon_features.head())
# Out:
#    num_total_packets  sum_packets  num_incoming_packets  \
# 0               1421       727552                  1300
# 1                518       265216                   438
# 2               1358       695296                  1240
# 3               1446       740352                  1324
# 4               1406       719872                  1291
#
#    frac_incoming_packets  num_outgoing_packets  frac_outgoing_packets  \
# 0               0.914849                   121               0.085151
# 1               0.845560                    80               0.154440
# 2               0.913108                   118               0.086892
# 3               0.915629                   122               0.084371
# 4               0.918208                   115               0.081792
#
#    average_outgoing_ordering  std_dev_outgoing_ordering  \
# 0                 773.322314                 515.483953
# 1                 226.162500                 139.231951
# 2                 786.110169                 472.735508
# 3                 820.139344                 513.916038
# 4                 789.608696                 503.993490
#
#    average_incoming_ordering  std_dev_incoming_ordering  ...  \
# 0                 704.106154                 398.486335  ...
# 1                 264.406393                 150.591146  ...
# 2                 668.259677                 381.878642  ...
# 3                 713.503021                 406.205288  ...
# 4                 694.740511                 395.028889  ...
#
#    incoming_packets_first30  outgoing_packets_first30  transmission_time_Q1  \
# 0                        21                         9                  3.88
# 1                        22                         8                  3.69
# 2                        23                         7                  5.06
# 3                        21                         9                  5.32
# 4                        22                         8                  4.18
#
#    transmission_time_Q2  transmission_time_Q3  transmission_time_Q4  \
# 0                  4.09                  4.69                 10.14
# 1                  4.80                  5.28                 10.16
# 2                  5.15                  5.79                 11.11
# 3                  5.57                  6.40                 13.36
# 4                  4.31                  5.14                 10.64
#
#    num_packets_per_second  mean_packets_per_second  std_packets_per_second  \
# 0              140.138067                 4.315749                1.128739
# 1               50.984252                 4.611815                1.371935
# 2              122.232223                 5.488969                1.179699
# 3              108.233533                 5.995512                1.709479
# 4              132.142857                 4.698869                1.297546
#
#    med_packets_per_second
# 0                    4.09
# 1                    4.80
# 2                    5.15
# 3                    5.57
# 4                    4.31
#
# [5 rows x 22 columns]

# %%
print(mon_labels.head())
# Out:
#    label
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
print(unmon_features.head())
# Out:
#    num_total_packets  sum_packets  num_incoming_packets  \
# 0                130        66560                   101
# 1               9927      5082624                  9189
# 2                359       183808                   285
# 3               9948      5093376                  9407
# 4               2508      1284096                  2215
#
#    frac_incoming_packets  num_outgoing_packets  frac_outgoing_packets  \
# 0               0.776923                    29               0.223077
# 1               0.925657                   738               0.074343
# 2               0.793872                    74               0.206128
# 3               0.945617                   541               0.054383
# 4               0.883174                   293               0.116826
#
#    average_outgoing_ordering  std_dev_outgoing_ordering  \
# 0                  36.758621                  27.053784
# 1                3845.246612                2885.461055
# 2                 155.905405                 111.145044
# 3                4667.994455                3120.454082
# 4                1227.269625                 778.715376
#
#    average_incoming_ordering  std_dev_incoming_ordering  ...  \
# 0                  72.465347                  36.304696  ...
# 1                5052.770595                2845.096286  ...
# 2                 184.996491                 100.730751  ...
# 3                4991.069735                2855.784563  ...
# 4                1256.969752                 716.374241  ...
#
#    incoming_packets_first30  outgoing_packets_first30  transmission_time_Q1  \
# 0                        17                        13                 2.920
# 1                        18                        12                 9.590
# 2                        17                        13                 7.525
# 3                        21                         9                 6.840
# 4                        27                         3                 7.400
#
#    transmission_time_Q2  transmission_time_Q3  transmission_time_Q4  \
# 0                  4.18                  4.84                  5.56
# 1                 10.23                 11.02                 11.88
# 2                  8.68                 12.30                 17.81
# 3                  7.64                  8.52                  9.17
# 4                  8.08                 13.09                 53.59
#
#    num_packets_per_second  mean_packets_per_second  std_packets_per_second  \
# 0               23.381295                 3.799462                1.309629
# 1              835.606061                 9.884457                1.613041
# 2               20.157215                 9.328440                3.082876
# 3             1084.841876                 7.584566                1.036050
# 4               46.799776                10.352085                5.565770
#
#    med_packets_per_second
# 0                    4.18
# 1                   10.23
# 2                    8.68
# 3                    7.64
# 4                    8.08
#
# [5 rows x 22 columns]

# %%
print(unmon_labels.head())
# Out:
#    label
# 0     -1
# 1     -1
# 2     -1
# 3     -1
# 4     -1

# %%
features = pd.concat([mon_features, unmon_features], axis=0, ignore_index=True)
print(features.head())
# Out:
#    num_total_packets  sum_packets  num_incoming_packets  \
# 0               1421       727552                  1300
# 1                518       265216                   438
# 2               1358       695296                  1240
# 3               1446       740352                  1324
# 4               1406       719872                  1291
#
#    frac_incoming_packets  num_outgoing_packets  frac_outgoing_packets  \
# 0               0.914849                   121               0.085151
# 1               0.845560                    80               0.154440
# 2               0.913108                   118               0.086892
# 3               0.915629                   122               0.084371
# 4               0.918208                   115               0.081792
#
#    average_outgoing_ordering  std_dev_outgoing_ordering  \
# 0                 773.322314                 515.483953
# 1                 226.162500                 139.231951
# 2                 786.110169                 472.735508
# 3                 820.139344                 513.916038
# 4                 789.608696                 503.993490
#
#    average_incoming_ordering  std_dev_incoming_ordering  ...  \
# 0                 704.106154                 398.486335  ...
# 1                 264.406393                 150.591146  ...
# 2                 668.259677                 381.878642  ...
# 3                 713.503021                 406.205288  ...
# 4                 694.740511                 395.028889  ...
#
#    incoming_packets_first30  outgoing_packets_first30  transmission_time_Q1  \
# 0                        21                         9                  3.88
# 1                        22                         8                  3.69
# 2                        23                         7                  5.06
# 3                        21                         9                  5.32
# 4                        22                         8                  4.18
#
#    transmission_time_Q2  transmission_time_Q3  transmission_time_Q4  \
# 0                  4.09                  4.69                 10.14
# 1                  4.80                  5.28                 10.16
# 2                  5.15                  5.79                 11.11
# 3                  5.57                  6.40                 13.36
# 4                  4.31                  5.14                 10.64
#
#    num_packets_per_second  mean_packets_per_second  std_packets_per_second  \
# 0              140.138067                 4.315749                1.128739
# 1               50.984252                 4.611815                1.371935
# 2              122.232223                 5.488969                1.179699
# 3              108.233533                 5.995512                1.709479
# 4              132.142857                 4.698869                1.297546
#
#    med_packets_per_second
# 0                    4.09
# 1                    4.80
# 2                    5.15
# 3                    5.57
# 4                    4.31
#
# [5 rows x 22 columns]

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29000 entries, 0 to 28999
# Data columns (total 22 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   num_total_packets                   29000 non-null  int64
#  1   sum_packets                         29000 non-null  int64
#  2   num_incoming_packets                29000 non-null  int64
#  3   frac_incoming_packets               29000 non-null  float64
#  4   num_outgoing_packets                29000 non-null  int64
#  5   frac_outgoing_packets               29000 non-null  float64
#  6   average_outgoing_ordering           29000 non-null  float64
#  7   std_dev_outgoing_ordering           29000 non-null  float64
#  8   average_incoming_ordering           29000 non-null  float64
#  9   std_dev_incoming_ordering           29000 non-null  float64
#  10  mean_of_the_sequence                29000 non-null  float64
#  11  alternative_packets_per_second_sum  29000 non-null  float64
#  12  incoming_packets_first30            29000 non-null  int64
#  13  outgoing_packets_first30            29000 non-null  int64
#  14  transmission_time_Q1                29000 non-null  float64
#  15  transmission_time_Q2                29000 non-null  float64
#  16  transmission_time_Q3                29000 non-null  float64
#  17  transmission_time_Q4                29000 non-null  float64
#  18  num_packets_per_second              29000 non-null  float64
#  19  mean_packets_per_second             29000 non-null  float64
#  20  std_packets_per_second              29000 non-null  float64
#  21  med_packets_per_second              29000 non-null  float64
# dtypes: float64(16), int64(6)
# memory usage: 4.9 MB

# %%
features.describe()
# Out:
#        num_total_packets   sum_packets  num_incoming_packets  \
# count       29000.000000  2.900000e+04          29000.000000
# mean         4384.463793  2.244845e+06           4035.842241
# std          3338.716956  1.709423e+06           3128.581869
# min            50.000000  2.560000e+04             25.000000
# 25%          1508.750000  7.724800e+05           1366.000000
# 50%          3535.500000  1.810176e+06           3220.000000
# 75%          7044.750000  3.606912e+06           6424.250000
# max          9993.000000  5.116416e+06           9698.000000
#
#        frac_incoming_packets  num_outgoing_packets  frac_outgoing_packets  \
# count           29000.000000          29000.000000           29000.000000
# mean                0.901916            348.621552               0.098084
# std                 0.052594            290.684381               0.052594
# min                 0.492754              6.000000               0.029197
# 25%                 0.881123            135.000000               0.061790
# 50%                 0.913618            289.000000               0.086382
# 75%                 0.938210            487.000000               0.118877
# max                 0.970803           4464.000000               0.507246
#
#        average_outgoing_ordering  std_dev_outgoing_ordering  \
# count               29000.000000               29000.000000
# mean                 2114.698276                1353.673322
# std                  1650.336495                1016.749568
# min                    10.000000                   7.127802
# 25%                   651.095726                 474.897209
# 50%                  1752.092736                1135.903549
# 75%                  3518.300889                2157.280420
# max                  7664.499381                3747.259674
#
#        average_incoming_ordering  std_dev_incoming_ordering  ...  \
# count               29000.000000               29000.000000  ...
# mean                 2188.099595                1251.405762  ...
# std                  1667.312774                 958.062700  ...
# min                    19.280000                  11.638710  ...
# 25%                   758.212649                 427.426375  ...
# 50%                  1767.667929                1002.526654  ...
# 75%                  3490.632175                2009.681842  ...
# max                  5142.500485                3031.825712  ...
#
#        incoming_packets_first30  outgoing_packets_first30  \
# count              29000.000000              29000.000000
# mean                  21.416448                  8.583552
# std                    1.915555                  1.915555
# min                   11.000000                  3.000000
# 25%                   20.000000                  7.000000
# 50%                   21.000000                  9.000000
# 75%                   23.000000                 10.000000
# max                   27.000000                 19.000000
#
#        transmission_time_Q1  transmission_time_Q2  transmission_time_Q3  \
# count          29000.000000          29000.000000          29000.000000
# mean               7.068046              8.924449             11.141436
# std                4.119637              5.698518              7.710923
# min                0.500000              1.010000              1.390000
# 25%                4.660000              5.540000              6.490000
# 50%                6.160000              7.450000              8.920000
# 75%                8.220000             10.250000             12.820000
# max               53.080000             55.260000             56.570000
#
#        transmission_time_Q4  num_packets_per_second  mean_packets_per_second  \
# count          29000.000000            29000.000000             29000.000000
# mean              26.524885              240.280271                 9.216102
# std               16.820603              285.093371                 5.581138
# min                1.600000                0.780572                 1.030417
# 25%               11.780000               68.985735                 5.783046
# 50%               22.015000              133.218498                 7.750339
# 75%               40.012500              272.753872                10.700278
# max               86.020000             2127.136752                51.401606
#
#        std_packets_per_second  med_packets_per_second
# count            29000.000000            29000.000000
# mean                 3.304990                8.924449
# std                  2.945260                5.698518
# min                  0.264664                1.010000
# 25%                  1.452936                5.540000
# 50%                  2.328445                7.450000
# 75%                  3.927127               10.250000
# max                 23.357901               55.260000
#
# [8 rows x 22 columns]

# %%
import matplotlib.pyplot as plt
mon_features.hist(bins=50, figsize=(20,15))
plt.show()

# %%
unmon_features.hist(bins=50, figsize=(20,15))
plt.show()
